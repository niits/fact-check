# %%
from src.modules.datasets.feverous.feverous import FeverousEvidenceFormat


dataset = FeverousEvidenceFormat.from_path('./data/dev.jsonl', './data/feverous_wikiv1.db')

# %%
sample = next(iter(dataset))

# %%
sample.evidence
# Out:
# [EvidenceItem(source='Algebraic logic', content='Passages:\n- **In mathematical logic, algebraic logic is the reasoning obtained by manipulating equations with free variables.**', context='Algebraic logic'),
#  EvidenceItem(source='Lindenbaum–Tarski algebra', content='Passages:\n- **In mathematical logic, the Lindenbaum–Tarski algebra (or Lindenbaum algebra) of a logical theory T consists of the equivalence classes of sentences of the theory (i.e., the quotient, under the equivalence relation ~ defined such that p ~ q exactly when p and q are provably equivalent in T).**', context='Lindenbaum–Tarski algebra'),
#  EvidenceItem(source='Lindenbaum–Tarski algebra', content='Passages:\n- **The Lindenbaum–Tarski algebra is considered the origin of the modern algebraic logic.**', context='Lindenbaum–Tarski algebra'),
# ...

# %%
for evidence_item in sample.evidence:
    print(evidence_item.content)
    print('---')
# Out:
# Passages:
# - **In mathematical logic, algebraic logic is the reasoning obtained by manipulating equations with free variables.**
# ---
# Passages:
# - **In mathematical logic, the Lindenbaum–Tarski algebra (or Lindenbaum algebra) of a logical theory T consists of the equivalence classes of sentences of the theory (i.e., the quotient, under the equivalence relation ~ defined such that p ~ q exactly when p and q are provably equivalent in T).**
# ---
# Passages:
# - **The Lindenbaum–Tarski algebra is considered the origin of the modern algebraic logic.**
# ---
# Passages:
# - **The Lindenbaum–Tarski algebra is thus the quotient algebra obtained by factoring the algebra of formulas by this congruence relation.**
# ---
# Table
# | Logical system | Lindenbaum–Tarski algebra |
# | --- | --- |
# | Classical sentential logic | **Boolean algebra** |
# | Intuitionistic propositional logic | Heyting algebra |
# | Łukasiewicz logic | MV-algebra |
# | Modal logic K | Modal algebra |
# ...
